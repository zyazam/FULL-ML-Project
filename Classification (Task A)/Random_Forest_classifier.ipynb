# %% [markdown]
# - ## ****Random Forest classifier****
#    - ### ****Reliability and Generalization: The Random Forest model achieved a ROC-AUC of 0.8149, which matches the Decision Tree but with a higher Accuracy (73.6%). This indicates that the ensemble method (combining multiple trees) provides a more stable and reliable prediction by reducing the noise found in single trees****

# %% [markdown]
# - ## ****Metric Breakdown****
#    - ### ****Recall (0.7413): This is the most critical success. The model correctly identified over 74% of the actual reorders. In a recommendation or inventory system, catching 3 out of 4 reorders is a very strong performance****
#    -  ### ****Precision (0.1551): While precision remains low (which is expected in highly imbalanced datasets like "Instacart"), it is slightly better than previous attempts. It means when the model predicts a reorder, there is a 15.5% chance it is correct****
#    -  ### ****MCC (0.2516): The Matthews Correlation Coefficient is positive and significant, proving that the model's predictions are much better than random guessing, despite the class imbalance****

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train_scaled, y_train)
evaluate_model(rf_model, X_val_scaled, y_val, "Random Forest Classifier")
# Out:
# --- Random Forest Classifier Performance Metrics ---
# Accuracy              : 0.7361
# Precision             : 0.1551
# Recall                : 0.7413
# F1-score              : 0.2566
# MCC                   : 0.2516
# ROC-AUC               : 0.8149
# Avg Precision (AP)    : 0.2579
# {'Accuracy': 0.7361190840550794,
#  'Precision': 0.15514905319360198,
#  'Recall': 0.74128343402073,
#  'F1-score': 0.25659360760967176,
#  'MCC': np.float64(0.25156142781407664),
#  'ROC-AUC': np.float64(0.8148796879147626),
#  'Avg Precision (AP)': np.float64(0.2578896374325291)}
